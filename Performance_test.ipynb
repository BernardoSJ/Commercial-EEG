# %%
import pandas as pd
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Desempeño computacional

# %%
df_dsi4 = pd.read_hdf('data/devices/DSI-4/DSI-4.hdf')
df_dsi7 = pd.read_hdf('data/devices/DSI-7/DSI-7.hdf')
df_emotiv = pd.read_hdf('data/devices/EMOTIV/EMOTIV.hdf')

# %%
proc_time = df_dsi4['elapsed time'].sum() + df_dsi7['elapsed time'].sum() + df_emotiv['elapsed time'].sum()
proc_time/3600
# Out:
# 87.35927020159032

# %%
windows = len(df_dsi4) + len(df_dsi7) + len(df_emotiv)
windows
# Out:
# 67693

# %%
window_size = 10
total_time = windows * window_size / 2
total_time/3600
# Out:
# 94.01805555555555

# %% [markdown]
# ## Tiempo de ejecución

# %% [markdown]
# ### DSI-4

# %%
df_dsi4['elapsed time'].describe()
# Out:
# count    17278.000000
# mean         4.482632
# std         50.732581
# min          2.774703
# 25%          3.749204
# 50%          3.881837
# 75%          4.175897
# max       6434.082396
# Name: elapsed time, dtype: float64

# %%
df_dsi4_n = df_dsi4[(np.abs(stats.zscore(df_dsi4['elapsed time'])) < 3)]

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(len(df_dsi4_n)), df_dsi4_n['elapsed time'])
plt.show()

# %%
df_dsi4['elapsed time'][:7000].describe()
# Out:
# count    7000.000000
# mean        3.988884
# std         0.298492
# min         3.320039
# 25%         3.792244
# 50%         3.860276
# 75%         4.086339
# max         5.417617
# Name: elapsed time, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_dsi4_n['elapsed time'][:7000], rug=True)
plt.xlabel('tiempo de cálculo (s)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(7000), df_dsi4['elapsed time'][:7000])
plt.xlabel('ventana', fontsize=14)
plt.ylabel('tiempo de cálculo (s)', fontsize=14)
plt.show()

# %%
print(len(df_dsi4_n['elapsed time'][7500:]))
df_dsi4_n['elapsed time'][7500:].describe()
# Out:
# 9774
# count    9774.000000
# mean        3.928876
# std         0.547693
# min         2.774703
# 25%         3.571906
# 50%         3.923564
# 75%         4.236077
# max        17.682465
# Name: elapsed time, dtype: float64

# %%
print(len(df_dsi4['elapsed time'][7500:]))
df_dsi4['elapsed time'][7500:].describe()
# Out:
# 9778
# count    9778.000000
# mean        4.863043
# std        67.437136
# min         2.774703
# 25%         3.571906
# 50%         3.923983
# 75%         4.237071
# max      6434.082396
# Name: elapsed time, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_dsi4_n['elapsed time'][7500:], rug=True)
plt.xlabel('tiempo de cálculo (s)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(len(df_dsi4_n[7500:])), df_dsi4_n['elapsed time'][7500:])
plt.xlabel('ventana', fontsize=14)
plt.ylabel('tiempo de cálculo (s)', fontsize=14)
plt.show()

# %% [markdown]
# ### DSI-7

# %%
df_dsi7['elapsed time'].describe()
# Out:
# count    19070.000000
# mean         5.813254
# std          0.354788
# min          3.515460
# 25%          5.696030
# 50%          5.795168
# 75%          5.951660
# max          7.943805
# Name: elapsed time, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_dsi7['elapsed time'], rug=True)
plt.xlabel('tiempo de cálculo (s)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(len(df_dsi7)), df_dsi7['elapsed time'])
plt.xlabel('ventana', fontsize=14)
plt.ylabel('tiempo de cálculo (s)', fontsize=14)
plt.show()

# %% [markdown]
# ### Emotiv

# %%
df_emotiv['elapsed time'].describe()
# Out:
# count    31345.000000
# mean         4.025641
# std          0.846008
# min          2.997957
# 25%          3.519554
# 50%          3.736009
# 75%          4.344381
# max         34.903480
# Name: elapsed time, dtype: float64

# %%
df_emotiv_n = df_emotiv[(np.abs(stats.zscore(df_emotiv['elapsed time'])) < 3)]

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_emotiv_n['elapsed time'], rug=True)
plt.xlabel('tiempo de cálculo (s)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(len(df_emotiv_n)), df_emotiv_n['elapsed time'])
plt.xlabel('ventana', fontsize=14)
plt.ylabel('tiempo de cálculo (s)', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_emotiv_n['elapsed time'][:8000], rug=True)
plt.xlabel('tiempo de cálculo (s)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(8000), df_emotiv_n['elapsed time'][:8000])
plt.xlabel('ventana', fontsize=14)
plt.ylabel('tiempo de cálculo (s)', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_emotiv_n['elapsed time'][9000:], rug=True)
plt.xlabel('tiempo de cálculo (s)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(range(len(df_emotiv_n[9000:])), df_emotiv_n['elapsed time'][9000:])
plt.xlabel('ventana', fontsize=14)
plt.ylabel('tiempo de cálculo (s)', fontsize=14)
plt.show()

# %%
df_emotiv_n['elapsed time'][:8000].describe()
# Out:
# count    8000.000000
# mean        4.336246
# std         0.162913
# min         2.997957
# 25%         4.254576
# 50%         4.300534
# 75%         4.370289
# max         6.357480
# Name: elapsed time, dtype: float64

# %%
df_emotiv_n['elapsed time'][9000:].describe()
# Out:
# count    21713.000000
# mean         3.760590
# std          0.417869
# min          3.104697
# 25%          3.485678
# 50%          3.567457
# 75%          3.797811
# max          6.536182
# Name: elapsed time, dtype: float64

# %% [markdown]
# ## Uso de memoria

# %%
(df_dsi4_n['memory usage'][:7000]/(1024**3)).describe()
# Out:
# count    7000.000000
# mean        1.863233
# std         0.081556
# min         1.636723
# 25%         1.849429
# 50%         1.911732
# 75%         1.915078
# max         1.918259
# Name: memory usage, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_dsi4_n['memory usage'][:7000]/(1024**3), rug=True)
plt.xlabel('Uso de memoria (GB)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
(df_dsi4_n['memory usage'][7500:]/(1024**2)).describe()
# Out:
# count    9774.000000
# mean     3842.504374
# std       202.902274
# min      3495.093750
# 25%      3702.397461
# 50%      3794.404297
# 75%      3944.801758
# max      4731.441406
# Name: memory usage, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_dsi4_n['memory usage'][7500:]/(1024**3), rug=True)
plt.xlabel('Uso de memoria (GB)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
(df_dsi7['memory usage']/(1024**3)).describe()
# Out:
# count    19070.000000
# mean         1.607151
# std          0.308799
# min          1.090439
# 25%          1.408923
# 50%          1.469664
# 75%          1.818249
# max          2.421474
# Name: memory usage, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_dsi7['memory usage']/(1024**3), rug=True)
plt.xlabel('Uso de memoria (GB)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_emotiv_n['memory usage'][:8000], rug=True)
plt.xlabel('Uso de memoria (GB)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
(df_emotiv_n['memory usage'][:8000]/(1024**2)).describe()
# Out:
# count    8000.000000
# mean     4255.970805
# std       142.094003
# min      4035.351562
# 25%      4176.425781
# 50%      4224.111328
# 75%      4288.260742
# max      5712.128906
# Name: memory usage, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df_emotiv_n['memory usage'][9000:], rug=True)
plt.xlabel('Uso de memoria (GB)', fontsize=10)
plt.ylabel('n', fontsize=10)
plt.show()

# %%
(df_emotiv_n['memory usage'][9000:]/(1024**2)).describe()
# Out:
# count    21713.000000
# mean      4050.592948
# std        210.717666
# min       3637.226562
# 25%       3895.011719
# 50%       4073.210938
# 75%       4141.894531
# max       5546.156250
# Name: memory usage, dtype: float64
